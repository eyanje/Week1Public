# %%
import pandas
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
dat = pandas.read_csv('BWSI_Dataset1.csv')
print(dat)
# Out:
#       SubjectID  Year  Sex  Age  Ethnicity  ParentEducation  MaritalStatus  \
# 0             1     6    1   49          3                5              1
# 1             2     2    1   37          3                4              5
# 2             3     1    1   70          1                1              1
# 3             4     6    2   38          3                5              3
# 4             5     2    2   85          4                1              2
# 5             6     6    2   23          1                1              6
# 6             7     5    2   53          3                3              1
# 7             8     6    2   42          3                4              1
# 8             9     3    1   62          3                3              3
# 9            10     1    2   38          4                3              5
# 10           11     2    2   68          1                1              2
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(dat['HoursTV'], dat['BMI'])
fig.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
